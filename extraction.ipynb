# %%
from selenium import webdriver
import os
from selenium.webdriver.common.by import By
import pandas as pd

# %%
website = "https://www.adamchoi.co.uk/teamgoals/detailed"
path = "/Users/ARMAN/Downloads/chromedriver-win64/chromedriver-win64"

# %%
#url = "https://google.com/"
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element("xpath",'//label[@analytics-event="All matches"]')
all_matches_button.click()

date = []
home_team = []
score = []
away_team = []


matches = driver.find_elements(By.TAG_NAME,'tr')
for match in matches:
    date.append(match.find_element(By.XPATH,'./td[1]').text)
    home = match.find_element(By.XPATH,'./td[2]').text
    home_team.append(home)
    print(home)
    score.append(match.find_element(By.XPATH,'./td[3]').text)
    away_team.append(match.find_element(By.XPATH,'./td[4]').text)

#driver.quit()
    
df = pd.DataFrame({'date':date,'home team':home_team,'score':score,'away team':away_team})
df.head(20)
# Out:
# Arsenal
# Crystal Palace
# Arsenal
# Arsenal
# Everton
# Arsenal
# Bournemouth
# Arsenal
# Chelsea
# Arsenal
# Newcastle
# Arsenal
# Brentford
# Arsenal
# Luton
# Aston Villa
# Arsenal
# Liverpool
# Arsenal
# Fulham
# Newcastle
# Aston Villa
# Burnley
# Liverpool
# Aston Villa
# Chelsea
# Aston Villa
# Wolves
# Aston Villa
# Aston Villa
# Nott'm Forest
# Aston Villa
# Tottenham
# Bournemouth
# Aston Villa
# Aston Villa
# Brentford
# Aston Villa
# Man United
# Aston Villa
# Everton
# Bournemouth
# Liverpool
# Bournemouth
# Brentford
# Bournemouth
# Brighton
# Bournemouth
# Everton
# Bournemouth
# Bournemouth
# Man City
# Bournemouth
# Sheffield United
# Bournemouth
# Crystal Palace
# Man United
# Nott'm Forest
# Bournemouth
# Tottenham
# Brentford
# Fulham
# Brentford
# Brentford
# Newcastle
# Brentford
# Nott'm Forest
# Man United
# Brentford
# Chelsea
# Brentford
# Liverpool
# Brentford
# Brentford
# Brighton
# Sheffield United
# Brentford
# Brentford
# Crystal Palace
# Brighton
# ...

# %%
df.to_csv('fb_teamgoals.csv')
